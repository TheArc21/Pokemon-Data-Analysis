# %% [markdown]
# # Basic Analysis

# %%
#importing all important packages
import numpy as np #linear algebra
import pandas as pd #data processing
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns #data visualisation
# %matplotlib inline

# %%
#Input Data
data = pd.read_csv("dataset/Pokemon.csv") #reading csv file and save it into a variable
data.head(10) #show the first 10 rows in data
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# # Data Cleaning
#
# There are some unneeded texts in Name column. Example: "VenusaurMega Venusaur" should be "Mega Venusaur". So we need to remove all characters before "Mega"

# %%
data.Name = data.Name.str.replace(".*(?=Mega)", "",regex=True)
data.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
data = data.set_index('Name') #change and set the index to the name attribute
data = data.drop(['#'],axis=1) #drop the columns with axis=1; axis=0 is for rows
data.head()
# Out:
#               Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur      Grass  Poison    318  45      49       49       65       65
# Ivysaur        Grass  Poison    405  60      62       63       80       80
# Venusaur       Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  Grass  Poison    625  80     100      123      122      120
# Charmander      Fire     NaN    309  39      52       43       60       50
#
#                Speed  Generation  Legendary
# Name
# Bulbasaur         45           1      False
# Ivysaur           60           1      False
# Venusaur          80           1      False
# Mega Venusaur     80           1      False
# Charmander        65           1      False

# %% [markdown]
# If we look at row 5, there is a NaN(missing value) type in the Type 2 row. We can choose to delete or fill in the data. But in this case if we delete rows that has NaN, then it will mess up our data. So we'll choose to fill it by copying the data from Type 1 column.

# %%
data['Type 2'].fillna(data['Type 1'], inplace=True)
data.head(10)
# Out:
#                  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur         Grass  Poison    318  45      49       49       65       65
# Ivysaur           Grass  Poison    405  60      62       63       80       80
# Venusaur          Grass  Poison    525  80      82       83      100      100
# Mega Venusaur     Grass  Poison    625  80     100      123      122      120
# Charmander         Fire    Fire    309  39      52       43       60       50
# Charmeleon         Fire    Fire    405  58      64       58       80       65
# Charizard          Fire  Flying    534  78      84       78      109       85
# Mega Charizard X   Fire  Dragon    634  78     130      111      130       85
# Mega Charizard Y   Fire  Flying    634  78     104       78      159      115
# Squirtle          Water   Water    314  44      48       65       50       64
#
#                   Speed  Generation  Legendary
# Name
# Bulbasaur            45           1      False
# Ivysaur              60           1      False
# Venusaur             80           1      False
# Mega Venusaur        80           1      False
# Charmander           65           1      False
# Charmeleon           80           1      False
# Charizard           100           1      False
# Mega Charizard X    100           1      False
# Mega Charizard Y    100           1      False
# Squirtle             43           1      False

# %% [markdown]
# # Frequency

# %% [markdown]
# Now lets see all the unique types in Type 1 and Type 2

# %%
print("Type 1:",data["Type 1"].unique(), "=", len(data["Type 1"].unique()))
print("Type 2:",data["Type 2"].unique(), "=", len(data["Type 2"].unique()))
# Out:
# Type 1: ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying'] = 18
# Type 2: ['Poison' 'Fire' 'Flying' 'Dragon' 'Water' 'Bug' 'Normal' 'Electric'
#  'Ground' 'Fairy' 'Grass' 'Fighting' 'Psychic' 'Steel' 'Ice' 'Rock' 'Dark'
#  'Ghost'] = 18

# %% [markdown]
# There are 18 unique types. Now we use value_counts() to count each unique type in Type 1 * and * Type 2

# %%
print(data["Type 1"].value_counts())
print(data["Type 2"].value_counts())
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64
# Flying      99
# Water       73
# Psychic     71
# Normal      65
# Grass       58
# Poison      49
# Ground      48
# Fighting    46
# Fire        40
# Fairy       38
# Electric    33
# Dark        30
# Dragon      29
# Steel       27
# Ice         27
# Ghost       24
# Rock        23
# Bug         20
# Name: Type 2, dtype: int64

# %% [markdown]
# We can conclude that the highest frequency in Type 1 is Water and in Type 2 is Flying. On the other hand, the lowest frequency in Type 1 is Flying and in Type 2 is Bug

# %% [markdown]
# # Strongest and Weakest Pokemon by types

# %%
strongest = data.sort_values(by='Total', ascending=False) #sorting the rows in descending order
strongest.drop_duplicates(subset=['Type 1'],keep='first')
#since the rows are now sorted in descending order
#thus we take the first row for every new type of pokemon i.e the table will check Type 1 of every pokemon
#The first pokemon of that type is the strongest for that type
#so we just keep the first row
# Out:
#                          Type 1   Type 2  Total   HP  Attack  Defense  \
# Name
# Mega Rayquaza            Dragon   Flying    780  105     180      100
# Mega Mewtwo Y           Psychic  Psychic    780  106     150       70
# KyogrePrimal Kyogre       Water    Water    770  100     150       90
# GroudonPrimal Groudon    Ground     Fire    770  100     180      160
# Arceus                   Normal   Normal    720  120     120      120
# Mega Metagross            Steel  Psychic    700   80     145      150
# Mega Tyranitar             Rock     Dark    700  100     164      150
# GiratinaOrigin Forme      Ghost   Dragon    680  150     120      100
# Ho-oh                      Fire   Flying    680  106     130       90
# Xerneas                   Fairy    Fairy    680  126     131       95
# Yveltal                    Dark   Flying    680  126     131       95
# Mega Sceptile             Grass   Dragon    630   70     110       75
# Mega Lucario           Fighting    Steel    625   70     145       88
# Mega Ampharos          Electric   Dragon    610   90      95      105
# Mega Scizor                 Bug    Steel    600   70     150      140
# Mega Glalie                 Ice      Ice    580   80     120       80
# TornadusTherian Forme    Flying   Flying    580   79     100       80
# Crobat                   Poison   Flying    535   85      90       80
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Mega Rayquaza              180      100    115           3       True
# Mega Mewtwo Y              194      120    140           1       True
# KyogrePrimal Kyogre        180      160     90           3       True
# GroudonPrimal Groudon      150       90     90           3       True
# Arceus                     120      120    120           4       True
# Mega Metagross             105      110    110           3      False
# Mega Tyranitar              95      120     71           2      False
# GiratinaOrigin Forme       120      100     90           4       True
# Ho-oh                      110      154     90           2       True
# Xerneas                    131       98     99           6       True
# Yveltal                    131       98     99           6       True
# Mega Sceptile              145       85    145           3      False
# Mega Lucario               140       70    112           4      False
# Mega Ampharos              165      110     45           2      False
# Mega Scizor                 65      100     75           2      False
# Mega Glalie                120       80    100           3      False
# TornadusTherian Forme      110       90    121           5       True
# Crobat                      70       80    130           2      False

# %% [markdown]
# So, we know who is the strongest pokemons by types. And also the strongest of the strongest pokemon is **Mega Rayquaza**, the Dragon type. And also we know that 10/18 Strongest Pokemons by types are Legendary.

# %% [markdown]
# Lets check the weakest pokemons now.

# %%
weakest = data.sort_values(by='Total') #sorting the rows in ascending order
weakest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#               Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Sunkern        Grass     Grass    180  30      30       30       30       30
# Azurill       Normal     Fairy    190  50      20       40       20       40
# Kricketot        Bug       Bug    194  37      25       41       25       41
# Ralts        Psychic     Fairy    198  28      25       25       45       35
# Magikarp       Water     Water    200  20      10       55       15       20
# Pichu       Electric  Electric    205  20      40       15       35       35
# Tyrogue     Fighting  Fighting    210  35      35       35       35       35
# Cleffa         Fairy     Fairy    218  50      25       28       45       55
# Poochyena       Dark      Dark    220  35      55       35       30       30
# Zubat         Poison    Flying    245  40      45       35       30       40
# Noibat        Flying    Dragon    245  40      30       35       45       40
# Swinub           Ice    Ground    250  50      50       40       30       30
# Slugma          Fire      Fire    250  40      40       40       70       40
# Diglett       Ground    Ground    265  10      55       25       35       45
# Litwick        Ghost      Fire    275  50      30       55       65       55
# Roggenrola      Rock      Rock    280  55      75       85       25       25
# Beldum         Steel   Psychic    300  40      55       80       35       60
# Bagon         Dragon    Dragon    300  45      75       60       40       30
#
#             Speed  Generation  Legendary
# Name
# Sunkern        30           2      False
# Azurill        20           3      False
# Kricketot      25           4      False
# Ralts          40           3      False
# Magikarp       80           1      False
# Pichu          60           2      False
# Tyrogue        35           2      False
# Cleffa         15           2      False
# Poochyena      35           3      False
# Zubat          55           1      False
# Noibat         55           6      False
# Swinub         50           2      False
# Slugma         20           2      False
# Diglett        95           1      False
# Litwick        20           5      False
# Roggenrola     15           5      False
# Beldum         30           3      False
# Bagon          50           3      False

# %% [markdown]
# We finally know who is the weakest pokemons by types. The weakest of the weakest pokemon is **Sunkern**, the Grass type. We can't find the Legendary category here.

# %% [markdown]
# # Fastest and Slowest Pokemon by types

# %%
fastest = data.sort_values(by='Speed', ascending=False) #sorting the rows in descending order
fastest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                      Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# DeoxysSpeed Forme   Psychic   Psychic    600   50      95       90       95
# Ninjask                 Bug    Flying    456   61      90       45       50
# Mega Aerodactyl        Rock    Flying    615   80     135       85       70
# Mega Sceptile         Grass    Dragon    630   70     110       75      145
# Electrode          Electric  Electric    480   60      50       70       80
# Mega Lopunny         Normal  Fighting    580   65     136       94       54
# Crobat               Poison    Flying    535   85      90       80       70
# Mega Gengar           Ghost    Poison    600   60      65       80      170
# Talonflame             Fire    Flying    499   78      81       71       74
# Darkrai                Dark      Dark    600   70      90       90      135
# Noivern              Flying    Dragon    535   85      70       80       97
# Greninja              Water      Dark    530   72      95       67      103
# Mega Salamence       Dragon    Flying    700   95     145      130      120
# Dugtrio              Ground    Ground    405   35      80       50       50
# Hawlucha           Fighting    Flying    500   78      92       75       74
# Froslass                Ice     Ghost    480   70      80       70       80
# Mega Metagross        Steel   Psychic    700   80     145      150      105
# Xerneas               Fairy     Fairy    680  126     131       95      131
#
#                    Sp. Def  Speed  Generation  Legendary
# Name
# DeoxysSpeed Forme       90    180           3       True
# Ninjask                 50    160           3      False
# Mega Aerodactyl         95    150           1      False
# Mega Sceptile           85    145           3      False
# Electrode               80    140           1      False
# Mega Lopunny            96    135           4      False
# Crobat                  80    130           2      False
# Mega Gengar             95    130           1      False
# Talonflame              69    126           6      False
# Darkrai                 90    125           4       True
# Noivern                 80    123           6      False
# Greninja                71    122           6      False
# Mega Salamence          90    120           3      False
# Dugtrio                 70    120           1      False
# Hawlucha                63    118           6      False
# Froslass                70    110           4      False
# Mega Metagross         110    110           3      False
# Xerneas                 98     99           6       True

# %% [markdown]
# The Fastest pokemon is **DeoxysSpeed Forme** which is a Legendary Psychic pokemon.

# %%
slowest = data.sort_values(by='Speed') #sorting the rows in ascending order
slowest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                 Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Munchlax        Normal    Normal    390  135      85       40       40
# Shuckle            Bug      Rock    505   20      10      230       10
# Ferroseed        Grass     Steel    305   44      50       91       24
# Bonsly            Rock      Rock    290   50      80       95       10
# Trapinch        Ground    Ground    290   45     100       45       45
# Wooper           Water    Ground    210   55      45       45       25
# Cleffa           Fairy     Fairy    218   50      25       28       45
# Litwick          Ghost      Fire    275   50      30       55       65
# Torkoal           Fire      Fire    470   70      85      140       85
# Mega Sableye      Dark     Ghost    480   50      85      125       85
# Solosis        Psychic   Psychic    290   45      30       40      105
# Bronzor          Steel   Psychic    300   57      24       86       24
# Makuhita      Fighting  Fighting    237   72      60       30       20
# Spheal             Ice     Water    290   70      40       50       55
# Grimer          Poison    Poison    325   80      80       50       40
# Mareep        Electric  Electric    280   55      40       40       65
# Goomy           Dragon    Dragon    300   45      50       35       55
# Noibat          Flying    Dragon    245   40      30       35       45
#
#               Sp. Def  Speed  Generation  Legendary
# Name
# Munchlax           85      5           4      False
# Shuckle           230      5           2      False
# Ferroseed          86     10           5      False
# Bonsly             45     10           4      False
# Trapinch           45     10           3      False
# Wooper             25     15           2      False
# Cleffa             55     15           2      False
# Litwick            55     20           5      False
# Torkoal            70     20           3      False
# Mega Sableye      115     20           3      False
# Solosis            50     20           5      False
# Bronzor            86     23           4      False
# Makuhita           30     25           3      False
# Spheal             50     25           3      False
# Grimer             50     25           1      False
# Mareep             45     35           2      False
# Goomy              75     40           6      False
# Noibat             40     55           6      False

# %% [markdown]
# This data shows that Bug type and Normal type have slowest pokemon compared other types.

# %% [markdown]
# # Summary of the data

# %%
data.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# # Data Visualization
# We will visualize the data in this stage. First I will make count plots to see value counts for each type.

# %% [markdown]
# ### Count Plot

# %%
sns.set(style = 'darkgrid')
f, ax = plt.subplots(2,1, figsize = (18,10)) #making 2 count plots 

sns.countplot(x = 'Type 1', data = data, order = data['Type 1'].value_counts().index ,ax = ax[0])
sns.countplot(x = 'Type 2', data = data, order = data['Type 2'].value_counts().index ,ax = ax[1])

plt.show()

# %% [markdown]
# ### Percentages for each type
# We can make a pie plot to get informations about that. But before that we must count all pokemon types from both columns and avoid double counting, because we copied the elements in the Type 1 column to the Type 2 column before. We do this because there are pokemon that don't have Type 2.

# %%
#we create a dictionary to make process easier
types_count = {'Grass' : 0, 'Fire' : 0, 'Water' : 0, 'Bug' : 0, 'Normal' : 0, 'Poison' : 0, 
               'Electric' : 0, 'Ground' : 0, 'Fairy' : 0, 'Fighting' : 0, 'Psychic' : 0, 
               'Rock' : 0, 'Ghost' : 0, 'Ice' : 0, 'Dragon' : 0, 'Dark' : 0, 'Steel' : 0, 'Flying' : 0}

type1 = data["Type 1"]
type2 = data["Type 2"]

for i in range(len(type1)):
    
    #first, count the Type 1 column
    types_count[type1[i]] += 1
    
    #now we count the Type 2 column and avoid double counting
    if type1[i] != type2[i]:
        types_count[type2[i]] += 1

for t in types_count:
    print("{:10} = {}".format(t,types_count[t]))
# Out:
# Grass      = 95
# Fire       = 64
# Water      = 126
# Bug        = 72
# Normal     = 102
# Poison     = 62
# Electric   = 50
# Ground     = 67
# Fairy      = 40
# Fighting   = 53
# Psychic    = 90
# Rock       = 58
# Ghost      = 46
# Ice        = 38
# Dragon     = 50
# Dark       = 51
# Steel      = 49
# Flying     = 101

# %% [markdown]
# We got overall count from both types, now it's time to get Type 1 count and Type 2 count.

# %%
type1_count = {'Grass' : 0, 'Fire' : 0, 'Water' : 0, 'Bug' : 0, 'Normal' : 0, 'Poison' : 0, 
               'Electric' : 0, 'Ground' : 0, 'Fairy' : 0, 'Fighting' : 0, 'Psychic' : 0, 
               'Rock' : 0, 'Ghost' : 0, 'Ice' : 0, 'Dragon' : 0, 'Dark' : 0, 'Steel' : 0,
               'Flying' : 0}
type2_count = {'Grass' : 0, 'Fire' : 0, 'Water' : 0, 'Bug' : 0, 'Normal' : 0, 'Poison' : 0, 
               'Electric' : 0, 'Ground' : 0, 'Fairy' : 0, 'Fighting' : 0, 'Psychic' : 0, 
               'Rock' : 0, 'Ghost' : 0, 'Ice' : 0, 'Dragon' : 0, 'Dark' : 0, 'Steel' : 0,
               'Flying' : 0}

for i in range(len(type1)):
    type1_count[type1[i]] += 1
    type2_count[type2[i]] += 1

print("TYPE 1")
for t in type1_count:
    print("{:10} = {}".format(t,type1_count[t]))
print("-------------------")
print("TYPE 2")
for t in type2_count:
    print("{:10} = {}".format(t,type2_count[t]))
# Out:
# TYPE 1
# Grass      = 70
# Fire       = 52
# Water      = 112
# Bug        = 69
# Normal     = 98
# Poison     = 28
# Electric   = 44
# Ground     = 32
# Fairy      = 17
# Fighting   = 27
# Psychic    = 57
# Rock       = 44
# Ghost      = 32
# Ice        = 24
# Dragon     = 32
# Dark       = 31
# Steel      = 27
# Flying     = 4
# -------------------
# TYPE 2
# Grass      = 58
# Fire       = 40
# Water      = 73
# Bug        = 20
# Normal     = 65
# Poison     = 49
# Electric   = 33
# Ground     = 48
# Fairy      = 38
# Fighting   = 46
# Psychic    = 71
# Rock       = 23
# Ghost      = 24
# Ice        = 27
# Dragon     = 29
# Dark       = 30
# Steel      = 27
# Flying     = 99

# %% [markdown]
# Now finally we can make the pie plot. We'll make 3 pie plots: Type 1 count, Type 2 count. and overall count.

# %%
f, axs = plt.subplots(2,2, figsize=(20,20))

labels ='Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric', 'Ground', \
        'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost' ,'Ice' ,'Dragon' ,'Dark' , \
        'Steel','Flying'
    
size0 = [95,64,126,72,102,62,50,67,40,53,90,58,46,38,50,51,49,101] #overall count
size1 = [70,52,112,69,98,28,44,32,17,27,57,44,32,24,32,31,27,4] #Type 1 count
size2 = [58,40,73,20,65,49,33,48,38,46,71,23,24,27,29,30,27,99] #Type 2 count

#Overall pie
axs[0,0].pie(size0, labels = labels, autopct='%1.1f%%' ,startangle = 90)
axs[0,0].axis("equal")
axs[0,0].set_title("Overall", size = 20)

#Type1 pie
axs[0,1].pie(size1, labels = labels, autopct='%1.1f%%' ,startangle = 180)
axs[0,1].axis("equal")
axs[0,1].set_title("Type 1", size = 20)

#Type2 pie
axs[1,0].pie(size2, labels = labels, autopct='%1.1f%%' ,startangle = 90)
axs[1,0].axis("equal")
axs[1,0].set_title("Type 2", size = 20)

f.delaxes(axs[1,1]) #deleting axs[1,1] so it will be white blank
plt.show()

# %% [markdown]
# # All stats analysis of the pokemons
# let's analyze all ratio data.

# %%
data2 = data.drop(['Generation', 'Total', 'Legendary'], axis = 1) #we drop some columns that unnecessary
data2.head()
# Out:
#               Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Name
# Bulbasaur      Grass  Poison  45      49       49       65       65     45
# Ivysaur        Grass  Poison  60      62       63       80       80     60
# Venusaur       Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# Charmander      Fire    Fire  39      52       43       60       50     65

# %%
#stats for the Attack by Type 1
sns.set_style("whitegrid")
f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.boxplot(data = data2, x = 'Type 1', y = 'Attack')
ax.set_title(label='Attack by Type 1', size = 20)

plt.show()

# %% [markdown]
# We can conclude that the Dragon type pokemon has an advantage over other types because they have a higher attack compared to other types. Let's see the starter pokemon : Fire, Water, and Grass. Fire Pokemons have a higher attack than Water and Grass. So it's very recommended to use it for attacking opponent for every beginner trainer. (If you ever played pokemon, then you can understand what starter pokemon is)

# %%
#stats for the Attack by Type 2
f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.boxplot(data = data2, x = 'Type 2', y = 'Attack')
ax.set_title(label='Attack by Type 2', size = 20)

plt.show()

# %% [markdown]
# And from this chart, we can conclude that Fighting pokemon have a higher attack than other pokemon types. All pokemons that have Fighting as their second type have higher attack value.

# %%
#stats for the Defense by Type 1
f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.violinplot(data = data2, x = 'Type 1', y = 'Defense')
ax.set_title(label='Defense by Type 1', size = 20)

plt.show()

# %% [markdown]
# This shows that **Steel**  pokemon have the highest defense compared the other types.

# %%
#stats for the Defense by Type 2
f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.violinplot(data = data2, x = 'Type 2', y = 'Defense')
ax.set_title(label='Defense by Type 2', size = 20)

plt.show()

# %% [markdown]
# And this shows that **Rock** pokemon is better than **Steel** pokemon in Defense values.

# %% [markdown]
# ## Strongest Generation

# %%
f, ax = plt.subplots(1,1, figsize = (20,10))
ax = sns.swarmplot(data = data, x = 'Generation', y= 'Total', hue = 'Legendary')

plt.axhline(data['Total'].mean(), color = 'red', linestyle = 'dashed') #giving a straight line on mean

plt.show()

# %% [markdown]
# This shows that 3rd generation has many strong pokemons. And also this data informed that all Legendary pokemon are strong or even the strongest.

# %% [markdown]
# ## Finding any correlation

# %%
f, ax = plt.subplots(1,1,figsize=(15,10))
ax = sns.heatmap(data.corr(), annot = True, cmap = 'winter') #data.corr() used to make correlation matrix

plt.show()

# %% [markdown]
# From the heat map above, the correlation between the attributes of the pokemon is not to much. The highest correlation is Sp. Attack and Total, following Attack *with *Total *and *Sp. Defense and Total.

# %% [markdown]
# Ok, that's all my analysis. Thank you for reading this notebook!
